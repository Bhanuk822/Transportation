# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/Bel_15min_0506_1610_2021.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   7/15/2021 15:40  1048575 non-null  object
#  1   4965             1048575 non-null  int64
#  2   14               1048575 non-null  int64
#  3   85.25            1048575 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 28.0+ MB

# %%
df.isnull().sum()
# Out:
# 7/15/2021 15:40    0
# 4965               0
# 14                 0
# 85.25              0
# dtype: int64

# %%
df.shape
# Out:
# (1048575, 4)

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (1048575, 4)

# %%
df.isnull().sum()
# Out:
# 7/15/2021 15:40    0
# 4965               0
# 14                 0
# 85.25              0
# dtype: int64

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (1048575, 4)

# %%
df.head()
# Out:
#    7/15/2021 15:40  4965  14      85.25
# 0   7/15/2021 3:00  3082  19  86.978070
# 1  7/15/2021 14:55  1056  21  81.265873
# 2   7/15/2021 8:45  3300   3  66.666667
# 3  6/17/2021 11:55   775   2  44.000000
# 4   6/17/2021 7:40  3859   1  84.000000

# %%
df.columns = ["Datetime" , "Street id" ,"count" ,"speed"]
df.head()
# Out:
#           Datetime  Street id  count      speed
# 0   7/15/2021 3:00       3082     19  86.978070
# 1  7/15/2021 14:55       1056     21  81.265873
# 2   7/15/2021 8:45       3300      3  66.666667
# 3  6/17/2021 11:55        775      2  44.000000
# 4   6/17/2021 7:40       3859      1  84.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Datetime   1048575 non-null  object
#  1   Street id  1048575 non-null  int64
#  2   count      1048575 non-null  int64
#  3   speed      1048575 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 36.0+ MB

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Street id'}>,
#         <AxesSubplot:title={'center':'count'}>],
#        [<AxesSubplot:title={'center':'speed'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.sort_values(by=['Datetime']).groupby(['Datetime']).agg({'count':'sum'}).plot(figsize=(20,5),
color = 'red', rot=45)
plt.show()

# %%
df.sort_values(by=['Datetime']).groupby(['Datetime']).agg({'count':'sum'}).plot(figsize=(20,5),
color = 'blue', rot=45)
plt.show()

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"])
df.head()
# Out:
#              Datetime  Street id  count      speed
# 0 2021-07-15 03:00:00       3082     19  86.978070
# 1 2021-07-15 14:55:00       1056     21  81.265873
# 2 2021-07-15 08:45:00       3300      3  66.666667
# 3 2021-06-17 11:55:00        775      2  44.000000
# 4 2021-06-17 07:40:00       3859      1  84.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Datetime   1048575 non-null  datetime64[ns]
#  1   Street id  1048575 non-null  int64
#  2   count      1048575 non-null  int64
#  3   speed      1048575 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 40.0 MB

# %%
df_datetime = df.groupby('Datetime')['count'].sum().reset_index()

# %%
df_datetime
# Out:
#                  Datetime  count
# 0     2021-06-05 00:00:00     17
# 1     2021-06-05 00:05:00     27
# 2     2021-06-05 00:10:00     36
# 3     2021-06-05 00:15:00      9
# 4     2021-06-05 00:20:00     26
# ...                   ...    ...
# 38458 2021-10-16 23:35:00      3
# 38459 2021-10-16 23:40:00      3
# 38460 2021-10-16 23:45:00      4
# 38461 2021-10-16 23:50:00      8
# 38462 2021-10-16 23:55:00      5
#
# [38463 rows x 2 columns]

# %%
df_datetime.head(10)
# Out:
#              Datetime  count
# 0 2021-06-05 00:00:00     17
# 1 2021-06-05 00:05:00     27
# 2 2021-06-05 00:10:00     36
# 3 2021-06-05 00:15:00      9
# 4 2021-06-05 00:20:00     26
# 5 2021-06-05 00:25:00     19
# 6 2021-06-05 00:30:00     15
# 7 2021-06-05 00:35:00     17
# 8 2021-06-05 00:40:00     15
# 9 2021-06-05 00:45:00     23

# %%
df_datetime['Time'] = df_datetime['Datetime'].dt.time

# %%
df_datetime.head()
# Out:
#              Datetime  count      Time
# 0 2021-06-05 00:00:00     17  00:00:00
# 1 2021-06-05 00:05:00     27  00:05:00
# 2 2021-06-05 00:10:00     36  00:10:00
# 3 2021-06-05 00:15:00      9  00:15:00
# 4 2021-06-05 00:20:00     26  00:20:00

# %%
df_datetime['Day'] = df_datetime['Datetime'].dt.dayofweek

# %%
df_datetime.head()
# Out:
#              Datetime  count      Time  Day
# 0 2021-06-05 00:00:00     17  00:00:00    5
# 1 2021-06-05 00:05:00     27  00:05:00    5
# 2 2021-06-05 00:10:00     36  00:10:00    5
# 3 2021-06-05 00:15:00      9  00:15:00    5
# 4 2021-06-05 00:20:00     26  00:20:00    5

# %%
df_datetime.Day.unique()
# Out:
# array([5, 6, 0, 1, 2, 3, 4], dtype=int64)

# %%
df_weekend = df_datetime[(df_datetime['Day'] == 5) | (df_datetime['Day'] == 6)]

# %%
df_weekdays = df_datetime[df_datetime['Day']<5]

# %%
df_weekdays.head()
# Out:
#                Datetime  count      Time  Day
# 538 2021-06-07 00:00:00     27  00:00:00    0
# 539 2021-06-07 00:05:00     41  00:05:00    0
# 540 2021-06-07 00:10:00     39  00:10:00    0
# 541 2021-06-07 00:15:00     35  00:15:00    0
# 542 2021-06-07 00:20:00     24  00:20:00    0

# %% [markdown]
# # Overall Truck counts Dsitribution

# %%
sns.set_style('whitegrid')
sns.distplot(df_datetime['count'], kde = True, color ='green', bins = 30)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Density'>

# %%
sns.violinplot(x="count", data=df_datetime, color = 'orange')
plt.title("Distribution of counts")
plt.show()

# %% [markdown]
# # Truck Average counts in Weekdays

# %%
sns.set_style('whitegrid')
sns.distplot(df_weekdays['count'], kde = True, color ='red', bins = 30)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Density'>

# %% [markdown]
# # Truck Average counts in Weekend

# %%
sns.set_style('whitegrid')
sns.distplot(df_weekend['count'], kde = True, color ='blue', bins = 30)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Density'>

# %%
df.head(2)
# Out:
#              Datetime  Street id  count      speed
# 0 2021-07-15 03:00:00       3082     19  86.978070
# 1 2021-07-15 14:55:00       1056     21  81.265873

# %%
df_speed = df.groupby('Datetime')['speed'].mean().reset_index()
df_speed.sort_values(by = 'speed')
# Out:
#                  Datetime       speed
# 26344 2021-09-04 21:30:00   42.500000
# 4289  2021-06-20 00:35:00   43.000000
# 26409 2021-09-05 02:55:00   43.125000
# 34056 2021-10-01 16:40:00   51.873270
# 20531 2021-08-15 13:45:00   52.916667
# ...                   ...         ...
# 10350 2021-07-11 01:50:00   96.654762
# 34435 2021-10-03 00:15:00   96.777778
# 241   2021-06-05 20:05:00   97.905556
# 20357 2021-08-14 23:15:00   98.000000
# 34331 2021-10-02 15:35:00  106.237847
#
# [38463 rows x 2 columns]

# %% [markdown]
# # Overall speed distribution

# %%
sns.distplot(df_speed['speed'], kde = True, color = 'green', bins = 30)
# Out:
# <AxesSubplot:xlabel='speed', ylabel='Density'>

# %%
df_speed["Day"] = df_speed['Datetime'].dt.dayofweek
df_speed.head(3)
# Out:
#              Datetime      speed  Day
# 0 2021-06-05 00:00:00  87.371212    5
# 1 2021-06-05 00:05:00  85.485764    5
# 2 2021-06-05 00:10:00  81.348039    5

# %%
df_speed_weekdays = df_speed[df_speed['Day']<5]
df_speed_weekdays.head()
# Out:
#                Datetime      speed  Day
# 538 2021-06-07 00:00:00  83.617188    0
# 539 2021-06-07 00:05:00  81.993345    0
# 540 2021-06-07 00:10:00  78.437753    0
# 541 2021-06-07 00:15:00  77.798246    0
# 542 2021-06-07 00:20:00  78.524306    0

# %% [markdown]
# # Weekdays speed distribution

# %%
sns.distplot(df_speed_weekdays['speed'], kde = True, color = 'red', bins = 30)
# Out:
# <AxesSubplot:xlabel='speed', ylabel='Density'>

# %%
df_speed_weekend = df_speed[(df_speed['Day'] == 5) | (df_speed['Day'] == 6)]
df_speed_weekend.head()
# Out:
#              Datetime      speed  Day
# 0 2021-06-05 00:00:00  87.371212    5
# 1 2021-06-05 00:05:00  85.485764    5
# 2 2021-06-05 00:10:00  81.348039    5
# 3 2021-06-05 00:15:00  77.142857    5
# 4 2021-06-05 00:20:00  80.890196    5

# %% [markdown]
# # Weekend Speed distribution

# %%
#overall speed distribution
sns.distplot(df_speed_weekend['speed'], kde = True, color = 'blue', bins = 30)
# Out:
# <AxesSubplot:xlabel='speed', ylabel='Density'>

# %%
df_speed['Time'] = df_speed['Datetime'].dt.time
df_speed.head(2)
# Out:
#              Datetime      speed  Day      Time
# 0 2021-06-05 00:00:00  87.371212    5  00:00:00
# 1 2021-06-05 00:05:00  85.485764    5  00:05:00

# %%
df_speed_time = df_speed.groupby('Time')['speed'].mean().reset_index()
df_speed_time.head()
# Out:
#        Time      speed
# 0  00:00:00  82.585961
# 1  00:05:00  82.135690
# 2  00:10:00  82.448936
# 3  00:15:00  82.372330
# 4  00:20:00  82.056760

# %%
df_speed_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    288 non-null    object
#  1   speed   288 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.4+ KB

# %%
df_speed_time['Time'] = df_speed_time['Time'].astype(str)

# %%
df_speed_time['Time'] = pd.to_timedelta(df_speed_time['Time'])

# %%
df_speed_time.max()
# Out:
# Time     0 days 23:55:00
# speed          83.009402
# dtype: object

# %%
# df_speed_time['Time'] = pd.to_datetime(df_speed_time['Time'])
# df_speed_time['Time'] = df_speed_time['Time'].astype(str)

# %% [markdown]
# # Overall Average Speed Vs Time

# %%
x_data = df_speed_time['Time']
y_data = df_speed_time['speed']

hours = df_speed_time['Time']/pd.Timedelta(hours = 1)
fig, ax = plt.subplots(figsize=(15, 4))
sns.lineplot(x=hours, y=y_data,color= 'red')


plt.show()

# %%
df_speed_weekdays['Time'] = df_speed_weekdays['Datetime'].dt.time
df_speed_weekdays.head(2)
# Out:
#                Datetime      speed  Day      Time
# 538 2021-06-07 00:00:00  83.617188    0  00:00:00
# 539 2021-06-07 00:05:00  81.993345    0  00:05:00

# %%
df_speed_weekdays_time = df_speed_weekdays.groupby('Time')['speed'].mean().reset_index()
df_speed_weekdays_time.head()
# Out:
#        Time      speed
# 0  00:00:00  82.086335
# 1  00:05:00  82.078913
# 2  00:10:00  82.180690
# 3  00:15:00  82.393378
# 4  00:20:00  81.921032

# %%
df_speed_weekdays_time['Time'] = df_speed_weekdays_time['Time'].astype(str)
df_speed_weekdays_time['Time'] = pd.to_timedelta(df_speed_weekdays_time['Time'])

# %% [markdown]
# # Weekdays Average Speed Vs Time

# %%
x_data = df_speed_weekdays_time['Time']
y_data = df_speed_weekdays_time['speed']

hours = df_speed_weekdays_time['Time']/pd.Timedelta(hours = 1)
fig, ax = plt.subplots(figsize=(15, 4))
sns.lineplot(x=hours, y=y_data,color= 'green')


plt.show()

# %%
df_speed_weekend['Time'] = df_speed_weekend['Datetime'].dt.time
df_speed_weekend.head()
# Out:
#              Datetime      speed  Day      Time
# 0 2021-06-05 00:00:00  87.371212    5  00:00:00
# 1 2021-06-05 00:05:00  85.485764    5  00:05:00
# 2 2021-06-05 00:10:00  81.348039    5  00:10:00
# 3 2021-06-05 00:15:00  77.142857    5  00:15:00
# 4 2021-06-05 00:20:00  80.890196    5  00:20:00

# %%
df_speed_weekend_time = df_speed_weekend.groupby('Time')['speed'].mean().reset_index()
df_speed_weekend_time.head()
# Out:
#        Time      speed
# 0  00:00:00  83.802997
# 1  00:05:00  82.277632
# 2  00:10:00  83.119550
# 3  00:15:00  82.319709
# 4  00:20:00  82.396078

# %% [markdown]
# # weekend Average Speed Vs Time

# %%
df_speed_weekend_time['Time'] = df_speed_weekend_time['Time'].astype(str)
df_speed_weekend_time['Time'] = pd.to_timedelta(df_speed_weekend_time['Time'])
x_data = df_speed_weekend_time['Time']
y_data = df_speed_weekend_time['speed']

hours = df_speed_weekend_time['Time']/pd.Timedelta(hours = 1)

fig, ax = plt.subplots(figsize=(15, 4))
sns.lineplot(x=hours, y=y_data,color= 'blue')


plt.show()

# %%
hours = df_speed_weekend_time['Time'] / pd.Timedelta(hours=1)

# %%
fig, ax = plt.subplots(figsize=(15, 5))


# create the first line plot
sns.lineplot(x=hours, y=df_speed_weekend_time['speed'], color='blue')

# create the second line plot on the same axis
sns.lineplot(x=hours, y=df_speed_weekdays_time['speed'], color='green')

ax.set_xlabel('Time')
ax.set_ylabel('Average Speed')
ax.legend(title='Legend', labels=['Weekend', 'Weekdays'])


plt.show()

# %% [markdown]
# # Visualize on ColumnDistribution

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/Bel_15min_0506_1610_2021.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   7/15/2021 15:40  1048575 non-null  object
#  1   4965             1048575 non-null  int64
#  2   14               1048575 non-null  int64
#  3   85.25            1048575 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 28.0+ MB

# %%
df
# Out:
#          7/15/2021 15:40  4965  14      85.25
# 0         7/15/2021 3:00  3082  19  86.978070
# 1        7/15/2021 14:55  1056  21  81.265873
# 2         7/15/2021 8:45  3300   3  66.666667
# 3        6/17/2021 11:55   775   2  44.000000
# 4         6/17/2021 7:40  3859   1  84.000000
# ...                  ...   ...  ..        ...
# 1048570   6/16/2021 4:00   815  29  83.545977
# 1048571   8/14/2021 6:30  3535   1  89.000000
# 1048572   8/14/2021 8:50  4688   1  88.000000
# 1048573  8/14/2021 15:10  4941   2  88.000000
# 1048574   8/17/2021 4:55  3106   4  87.250000
#
# [1048575 rows x 4 columns]

# %%
df.head()
# Out:
#    7/15/2021 15:40  4965  14      85.25
# 0   7/15/2021 3:00  3082  19  86.978070
# 1  7/15/2021 14:55  1056  21  81.265873
# 2   7/15/2021 8:45  3300   3  66.666667
# 3  6/17/2021 11:55   775   2  44.000000
# 4   6/17/2021 7:40  3859   1  84.000000

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/Bel_15min_0506_1610_2021.csv')
df.columns = ['Datetime','Street_id','Count','Speed of Vehicle']
nRow , nCol = df.shape

# %%
df
# Out:
#                 Datetime  Street_id  Count  Speed of Vehicle
# 0         7/15/2021 3:00       3082     19         86.978070
# 1        7/15/2021 14:55       1056     21         81.265873
# 2         7/15/2021 8:45       3300      3         66.666667
# 3        6/17/2021 11:55        775      2         44.000000
# 4         6/17/2021 7:40       3859      1         84.000000
# ...                  ...        ...    ...               ...
# 1048570   6/16/2021 4:00        815     29         83.545977
# 1048571   8/14/2021 6:30       3535      1         89.000000
# 1048572   8/14/2021 8:50       4688      1         88.000000
# 1048573  8/14/2021 15:10       4941      2         88.000000
# 1048574   8/17/2021 4:55       3106      4         87.250000
#
# [1048575 rows x 4 columns]

# %%
df.dataframeName = 'Bel_15min_0101_0103_2019.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1048575 rows and 4 columns

# %%
df.head(5)
# Out:
#           Datetime  Street_id  Count  Speed of Vehicle
# 0   7/15/2021 3:00       3082     19         86.978070
# 1  7/15/2021 14:55       1056     21         81.265873
# 2   7/15/2021 8:45       3300      3         66.666667
# 3  6/17/2021 11:55        775      2         44.000000
# 4   6/17/2021 7:40       3859      1         84.000000

# %%
def CorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df[[col for col in df if df[col].nunique() > 1]]
    if df.shape[1] < 2:
        print(f' non-NaN ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.show()

# %%
def ScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) 
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] 
    columnNames = list(df)
    if len(columnNames) > 10: 
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.isnull().sum()
# Out:
# Datetime            0
# Street_id           0
# Count               0
# Speed of Vehicle    0
# dtype: int64

# %%
df.shape
# Out:
# (1048575, 4)

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (1048575, 4)

# %% [markdown]
# # Graphs

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Street_id'}>,
#         <AxesSubplot:title={'center':'Count'}>],
#        [<AxesSubplot:title={'center':'Speed of Vehicle'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # PerColumnDistribution

# %%
CorrelationMatrix(df,8)

# %%
ScatterMatrix(df, 8, 8)

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/And_05min_1303_0606_2021.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624184 entries, 0 to 624183
# Data columns (total 4 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   2021-04-15 07:25:00  624184 non-null  object
#  1   148.0                624184 non-null  float64
#  2   1                    624184 non-null  int64
#  3   33.0                 624184 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 16.7+ MB

# %%
df
# Out:
#         2021-04-15 07:25:00   148.0  1  33.0
# 0       2021-04-27 06:40:00   412.0  1  37.0
# 1       2021-03-29 12:40:00  2152.0  2  23.5
# 2       2021-04-17 17:35:00  2352.0  1  13.0
# 3       2021-04-07 07:00:00  1266.0  1  68.0
# 4       2021-05-24 15:00:00  1848.0  1   0.0
# ...                     ...     ... ..   ...
# 624179  2021-05-12 19:10:00  2197.0  1  35.0
# 624180  2021-05-05 11:45:00   904.0  1  18.0
# 624181  2021-03-28 03:45:00  1384.0  1  28.0
# 624182  2021-06-01 12:40:00  1037.0  1  21.0
# 624183  2021-05-04 11:10:00   442.0  1   0.0
#
# [624184 rows x 4 columns]

# %%
df.head()
# Out:
#    2021-04-15 07:25:00   148.0  1  33.0
# 0  2021-04-27 06:40:00   412.0  1  37.0
# 1  2021-03-29 12:40:00  2152.0  2  23.5
# 2  2021-04-17 17:35:00  2352.0  1  13.0
# 3  2021-04-07 07:00:00  1266.0  1  68.0
# 4  2021-05-24 15:00:00  1848.0  1   0.0

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/And_05min_1303_0606_2021.csv')
df.columns = ['Datetime','Street_id','Count','Speed of Vehicle']
nRow , nCol = df.shape

# %%
df.dataframeName = 'Bel_60min_0101_0103_2019.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 624184 rows and 4 columns

# %%
df.head(5)
# Out:
#               Datetime  Street_id  Count  Speed of Vehicle
# 0  2021-04-27 06:40:00      412.0      1              37.0
# 1  2021-03-29 12:40:00     2152.0      2              23.5
# 2  2021-04-17 17:35:00     2352.0      1              13.0
# 3  2021-04-07 07:00:00     1266.0      1              68.0
# 4  2021-05-24 15:00:00     1848.0      1               0.0

# %%
df.isnull().sum()
# Out:
# Datetime            0
# Street_id           0
# Count               0
# Speed of Vehicle    0
# dtype: int64

# %%
df.shape
# Out:
# (624184, 4)

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (624184, 4)

# %% [markdown]
# # Graphs

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Street_id'}>,
#         <AxesSubplot:title={'center':'Count'}>],
#        [<AxesSubplot:title={'center':'Speed of Vehicle'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
CorrelationMatrix(df,8)

# %%
ScatterMatrix(df, 8, 8)

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/Bxl_15min_1303_0606_2021.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1743611 entries, 0 to 1743610
# Data columns (total 4 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   2021-04-26 12:00:00  object
#  1   3295.0               float64
#  2   2                    int64
#  3   68.0                 float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 46.6+ MB

# %%
df
# Out:
#          2021-04-26 12:00:00       3295.0  2       68.0
# 0        2021-04-26 07:00:00  4126.000000  7  21.642857
# 1        2021-05-11 07:30:00  1230.000000  3  18.666667
# 2        2021-05-21 12:30:00  1762.000000  6  26.166667
# 3        2021-03-19 09:30:00  3301.000000  3  78.000000
# 4        2021-06-03 03:00:00   737.000000  2  70.000000
# ...                      ...          ... ..        ...
# 1743606                  NaN    72.409091  0  11.000000
# 1743607                  NaN    40.217949  0  26.000000
# 1743608                  NaN     7.866667  0   5.000000
# 1743609                  NaN    37.858974  0  13.000000
# 1743610                  NaN    31.507937  0  21.000000
#
# [1743611 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# 2021-04-26 12:00:00    18227
# 3295.0                     0
# 2                          0
# 68.0                       0
# dtype: int64

# %%
df.shape
# Out:
# (1743611, 4)

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (1725384, 4)

# %%
df = pd.read_csv('C:/Users/User/Documents/Group 3 project/Bxl_15min_1303_0606_2021.csv')
df.columns = ['Datetime','Street_id','Count','Speed of Vehicle']
nRow , nCol = df.shape

# %%
df.dataframeName = 'Bxl_15min_1303_0606_2021.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1743611 rows and 4 columns

# %%
CorrelationMatrix(df,8)

# %%
ScatterMatrix(df, 8, 8)
